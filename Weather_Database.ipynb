# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import w_key

from pprint import pprint

import time

# %%
lats = np.random.uniform(low=-90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Starting URL for Weather Map API Call.
url_weather = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + w_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url_weather + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yima
# Processing Record 2 of Set 1 | gorontalo
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | celestun
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | ibra
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | pacific grove
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | kupang
# Processing Record 21 of Set 1 | beringovskiy
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | areosa
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | baker city
# Processing Record 28 of Set 1 | enumclaw
# Processing Record 29 of Set 1 | tara
# Processing Record 30 of Set 1 | marovoay
# Processing Record 31 of Set 1 | aojiang
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | corcoran
# Processing Record 34 of Set 1 | ranau
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | alyangula
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | hirado
# Processing Record 40 of Set 1 | talaya
# Processing Record 41 of Set 1 | saint anthony
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | bambanglipuro
# Processing Record 45 of Set 1 | karasjok
# Processing Record 46 of Set 1 | terre haute
# Processing Record 47 of Set 1 | buldana
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | bubaque
# Processing Record 50 of Set 1 | yulara
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | novomykolayivka
# Processing Record 3 of Set 2 | makakilo city
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | mvuma
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | pochutla
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | cartagena
# Processing Record 11 of Set 2 | taoudenni
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | olafsvik
# Processing Record 16 of Set 2 | takoradi
# Processing Record 17 of Set 2 | belmonte
# Processing Record 18 of Set 2 | pisco
# Processing Record 19 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 2 | outjo
# Processing Record 21 of Set 2 | pangnirtung
# Processing Record 22 of Set 2 | senno
# Processing Record 23 of Set 2 | champerico
# Processing Record 24 of Set 2 | iquique
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | coquimbo
# Processing Record 27 of Set 2 | ginir
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | samut songkhram
# Processing Record 30 of Set 2 | excelsior springs
# Processing Record 31 of Set 2 | kirakira
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | mangrol
# Processing Record 34 of Set 2 | saint-leu
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | hutchinson
# Processing Record 38 of Set 2 | padang
# Processing Record 39 of Set 2 | scarborough
# Processing Record 40 of Set 2 | la ronge
# Processing Record 41 of Set 2 | meulaboh
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | sisimiut
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | andrychow
# Processing Record 48 of Set 2 | vestmannaeyjar
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | rahimatpur
# Processing Record 1 of Set 3 | viedma
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | arraial do cabo
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | gushikawa
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | cholan
# City not found. Skipping...
# Processing Record 8 of Set 3 | nara
# Processing Record 9 of Set 3 | xai-xai
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | moberly
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | hamilton
# Processing Record 15 of Set 3 | najran
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | sungurlu
# Processing Record 18 of Set 3 | nuuk
# Processing Record 19 of Set 3 | campbell river
# Processing Record 20 of Set 3 | vila velha
# Processing Record 21 of Set 3 | phetchaburi
# Processing Record 22 of Set 3 | port-gentil
# Processing Record 23 of Set 3 | chissamba
# Processing Record 24 of Set 3 | batsfjord
# Processing Record 25 of Set 3 | leiyang
# Processing Record 26 of Set 3 | dingle
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | chicama
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | isangel
# Processing Record 33 of Set 3 | dunedin
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | guanambi
# Processing Record 36 of Set 3 | chokurdakh
# Processing Record 37 of Set 3 | zgorzelec
# Processing Record 38 of Set 3 | hobart
# Processing Record 39 of Set 3 | pyaozerskiy
# Processing Record 40 of Set 3 | cosala
# Processing Record 41 of Set 3 | umm kaddadah
# Processing Record 42 of Set 3 | along
# Processing Record 43 of Set 3 | ayan
# Processing Record 44 of Set 3 | grand island
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | ixtapa
# Processing Record 47 of Set 3 | masallatah
# Processing Record 48 of Set 3 | impfondo
# Processing Record 49 of Set 3 | kuytun
# Processing Record 50 of Set 3 | amahai
# Processing Record 1 of Set 4 | bengkulu
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | mount gambier
# Processing Record 4 of Set 4 | karwar
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | pallasovka
# Processing Record 7 of Set 4 | san francisco
# Processing Record 8 of Set 4 | khailar
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | gorgan
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | sokolo
# Processing Record 13 of Set 4 | faya
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | ushtobe
# Processing Record 16 of Set 4 | guerrero negro
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | domoni
# Processing Record 19 of Set 4 | leh
# Processing Record 20 of Set 4 | vilcun
# Processing Record 21 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 4 | ahuimanu
# Processing Record 23 of Set 4 | andilamena
# Processing Record 24 of Set 4 | manzil jamil
# City not found. Skipping...
# Processing Record 25 of Set 4 | juneau
# Processing Record 26 of Set 4 | camalu
# Processing Record 27 of Set 4 | vostok
# Processing Record 28 of Set 4 | khash
# Processing Record 29 of Set 4 | dubbo
# Processing Record 30 of Set 4 | lima
# Processing Record 31 of Set 4 | borgarnes
# Processing Record 32 of Set 4 | cherskiy
# Processing Record 33 of Set 4 | zhezkazgan
# Processing Record 34 of Set 4 | rio negro
# Processing Record 35 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | biak
# Processing Record 38 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | barcelos
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | krasnoselkup
# Processing Record 44 of Set 4 | puerto colombia
# Processing Record 45 of Set 4 | virginia beach
# Processing Record 46 of Set 4 | vitim
# Processing Record 47 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 4 | kashin
# Processing Record 49 of Set 4 | quatre cocos
# Processing Record 50 of Set 4 | buchanan
# Processing Record 1 of Set 5 | nome
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | vao
# Processing Record 4 of Set 5 | opotiki
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 7 of Set 5 | roma
# Processing Record 8 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 5 | ilheus
# Processing Record 10 of Set 5 | karratha
# Processing Record 11 of Set 5 | la palma
# Processing Record 12 of Set 5 | sorong
# Processing Record 13 of Set 5 | srednekolymsk
# Processing Record 14 of Set 5 | port hueneme
# Processing Record 15 of Set 5 | nishihara
# Processing Record 16 of Set 5 | ardalstangen
# Processing Record 17 of Set 5 | menongue
# Processing Record 18 of Set 5 | tabou
# Processing Record 19 of Set 5 | kudahuvadhoo
# Processing Record 20 of Set 5 | kamina
# Processing Record 21 of Set 5 | xocali
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | san ramon
# Processing Record 24 of Set 5 | gezing
# Processing Record 25 of Set 5 | ahipara
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 5 | zawadzkie
# Processing Record 29 of Set 5 | byron bay
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | faanui
# Processing Record 32 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | sosva
# Processing Record 35 of Set 5 | vila
# Processing Record 36 of Set 5 | okato
# Processing Record 37 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 5 | norman wells
# Processing Record 39 of Set 5 | lukovetskiy
# Processing Record 40 of Set 5 | manokwari
# Processing Record 41 of Set 5 | tasiilaq
# Processing Record 42 of Set 5 | lucea
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 5 | poum
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | jumla
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | rawson
# Processing Record 50 of Set 5 | tommot
# Processing Record 1 of Set 6 | wana
# Processing Record 2 of Set 6 | marsala
# Processing Record 3 of Set 6 | vardo
# Processing Record 4 of Set 6 | quimper
# Processing Record 5 of Set 6 | nurota
# Processing Record 6 of Set 6 | aksha
# Processing Record 7 of Set 6 | portland
# Processing Record 8 of Set 6 | mae ramat
# Processing Record 9 of Set 6 | mountain home
# Processing Record 10 of Set 6 | santa marta de tormes
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | yumen
# Processing Record 13 of Set 6 | ponta delgada
# Processing Record 14 of Set 6 | mackay
# Processing Record 15 of Set 6 | luanda
# Processing Record 16 of Set 6 | mahon
# Processing Record 17 of Set 6 | sur
# Processing Record 18 of Set 6 | salym
# Processing Record 19 of Set 6 | marsh harbour
# Processing Record 20 of Set 6 | san quintin
# Processing Record 21 of Set 6 | pevek
# Processing Record 22 of Set 6 | ust-kan
# Processing Record 23 of Set 6 | los llanos de aridane
# Processing Record 24 of Set 6 | alamosa
# Processing Record 25 of Set 6 | meppel
# Processing Record 26 of Set 6 | thiruvananthapuram
# Processing Record 27 of Set 6 | amarante do maranhao
# Processing Record 28 of Set 6 | oksfjord
# Processing Record 29 of Set 6 | tortoli
# Processing Record 30 of Set 6 | svay rieng
# Processing Record 31 of Set 6 | deder
# Processing Record 32 of Set 6 | saldanha
# Processing Record 33 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 6 | sitka
# Processing Record 35 of Set 6 | mount isa
# Processing Record 36 of Set 6 | kachiry
# Processing Record 37 of Set 6 | miyako
# Processing Record 38 of Set 6 | mehamn
# Processing Record 39 of Set 6 | dubuque
# Processing Record 40 of Set 6 | raudeberg
# Processing Record 41 of Set 6 | rio gallegos
# Processing Record 42 of Set 6 | quchan
# Processing Record 43 of Set 6 | katsuura
# Processing Record 44 of Set 6 | zhangye
# Processing Record 45 of Set 6 | sunrise manor
# Processing Record 46 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 6 | anloga
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | atar
# Processing Record 50 of Set 6 | rorvik
# Processing Record 1 of Set 7 | hasaki
# Processing Record 2 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 3 of Set 7 | beysehir
# Processing Record 4 of Set 7 | samarai
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | tromso
# Processing Record 7 of Set 7 | cockburn town
# Processing Record 8 of Set 7 | nabire
# Processing Record 9 of Set 7 | marawi
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | belle fourche
# Processing Record 12 of Set 7 | lodwar
# Processing Record 13 of Set 7 | loreto
# Processing Record 14 of Set 7 | zhigalovo
# Processing Record 15 of Set 7 | soyo
# Processing Record 16 of Set 7 | mwaya
# Processing Record 17 of Set 7 | bati
# Processing Record 18 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 7 | kloulklubed
# Processing Record 20 of Set 7 | rehti
# Processing Record 21 of Set 7 | port augusta
# Processing Record 22 of Set 7 | bansang
# Processing Record 23 of Set 7 | sarwar
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 26 of Set 7 | narsaq
# Processing Record 27 of Set 7 | nantucket
# Processing Record 28 of Set 7 | houma
# Processing Record 29 of Set 7 | pitimbu
# Processing Record 30 of Set 7 | mogadishu
# Processing Record 31 of Set 7 | svetlogorsk
# Processing Record 32 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | te anau
# Processing Record 35 of Set 7 | doha
# Processing Record 36 of Set 7 | tazovskiy
# Processing Record 37 of Set 7 | tual
# Processing Record 38 of Set 7 | atasu
# Processing Record 39 of Set 7 | oshawa
# Processing Record 40 of Set 7 | sabha
# Processing Record 41 of Set 7 | san patricio
# Processing Record 42 of Set 7 | muros
# Processing Record 43 of Set 7 | vidim
# Processing Record 44 of Set 7 | khalkhal
# Processing Record 45 of Set 7 | kushiro
# Processing Record 46 of Set 7 | saint-philippe
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | upernavik
# Processing Record 49 of Set 7 | sioux lookout
# Processing Record 50 of Set 7 | ballina
# Processing Record 1 of Set 8 | aklavik
# Processing Record 2 of Set 8 | bangkalan
# Processing Record 3 of Set 8 | seoul
# Processing Record 4 of Set 8 | honningsvag
# Processing Record 5 of Set 8 | cabo san lucas
# Processing Record 6 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 7 of Set 8 | palana
# Processing Record 8 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 8 | manyana
# Processing Record 10 of Set 8 | iskateley
# Processing Record 11 of Set 8 | tateyama
# Processing Record 12 of Set 8 | riyadh
# Processing Record 13 of Set 8 | kyren
# Processing Record 14 of Set 8 | buraydah
# Processing Record 15 of Set 8 | talbahat
# Processing Record 16 of Set 8 | zhigansk
# Processing Record 17 of Set 8 | inzer
# Processing Record 18 of Set 8 | havre-saint-pierre
# Processing Record 19 of Set 8 | igarka
# Processing Record 20 of Set 8 | calabozo
# Processing Record 21 of Set 8 | fort nelson
# Processing Record 22 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 8 | fort-shevchenko
# Processing Record 24 of Set 8 | kavieng
# Processing Record 25 of Set 8 | antofagasta
# Processing Record 26 of Set 8 | laguna
# Processing Record 27 of Set 8 | mendeleyevsk
# Processing Record 28 of Set 8 | bilimbay
# Processing Record 29 of Set 8 | rumoi
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | balikpapan
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | neryungri
# Processing Record 34 of Set 8 | ucluelet
# Processing Record 35 of Set 8 | amposta
# Processing Record 36 of Set 8 | sayyan
# Processing Record 37 of Set 8 | abu samrah
# Processing Record 38 of Set 8 | tiksi
# Processing Record 39 of Set 8 | ostrovnoy
# Processing Record 40 of Set 8 | komsomolskiy
# Processing Record 41 of Set 8 | adrar
# Processing Record 42 of Set 8 | xingyi
# Processing Record 43 of Set 8 | chernyshevskiy
# Processing Record 44 of Set 8 | harper
# Processing Record 45 of Set 8 | melfi
# Processing Record 46 of Set 8 | saint-augustin
# Processing Record 47 of Set 8 | port-cartier
# Processing Record 48 of Set 8 | cuiluan
# Processing Record 49 of Set 8 | waingapu
# Processing Record 50 of Set 8 | natal
# Processing Record 1 of Set 9 | lethem
# Processing Record 2 of Set 9 | fort walton beach
# Processing Record 3 of Set 9 | kenai
# Processing Record 4 of Set 9 | biskamzha
# Processing Record 5 of Set 9 | kahului
# Processing Record 6 of Set 9 | ovre ardal
# Processing Record 7 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 9 | lerwick
# Processing Record 9 of Set 9 | tura
# Processing Record 10 of Set 9 | martinsville
# Processing Record 11 of Set 9 | valdemarpils
# Processing Record 12 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 9 | nouakchott
# Processing Record 14 of Set 9 | san carlos de bariloche
# Processing Record 15 of Set 9 | belyy yar
# Processing Record 16 of Set 9 | aykhal
# Processing Record 17 of Set 9 | nouadhibou
# Processing Record 18 of Set 9 | alofi
# Processing Record 19 of Set 9 | saint george
# Processing Record 20 of Set 9 | ilulissat
# Processing Record 21 of Set 9 | sampit
# Processing Record 22 of Set 9 | komatipoort
# Processing Record 23 of Set 9 | oga
# Processing Record 24 of Set 9 | the woodlands
# Processing Record 25 of Set 9 | oistins
# Processing Record 26 of Set 9 | cururupu
# Processing Record 27 of Set 9 | sauk village
# Processing Record 28 of Set 9 | smithers
# Processing Record 29 of Set 9 | lengshuitan
# Processing Record 30 of Set 9 | amazar
# Processing Record 31 of Set 9 | wetter
# Processing Record 32 of Set 9 | hofn
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | kalispell
# Processing Record 35 of Set 9 | mana
# Processing Record 36 of Set 9 | thinadhoo
# Processing Record 37 of Set 9 | beira
# Processing Record 38 of Set 9 | foster city
# Processing Record 39 of Set 9 | cabedelo
# Processing Record 40 of Set 9 | victoria
# Processing Record 41 of Set 9 | westport
# Processing Record 42 of Set 9 | gat
# Processing Record 43 of Set 9 | synya
# Processing Record 44 of Set 9 | ambon
# Processing Record 45 of Set 9 | spaichingen
# Processing Record 46 of Set 9 | pekan
# Processing Record 47 of Set 9 | jibuti
# Processing Record 48 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 9 | todos santos
# Processing Record 50 of Set 9 | whitehorse
# Processing Record 1 of Set 10 | mardin
# Processing Record 2 of Set 10 | karla
# Processing Record 3 of Set 10 | biritiba-mirim
# Processing Record 4 of Set 10 | xuddur
# Processing Record 5 of Set 10 | katobu
# Processing Record 6 of Set 10 | ruian
# City not found. Skipping...
# Processing Record 7 of Set 10 | northam
# Processing Record 8 of Set 10 | usinsk
# Processing Record 9 of Set 10 | sechura
# Processing Record 10 of Set 10 | aktash
# Processing Record 11 of Set 10 | flinders
# Processing Record 12 of Set 10 | killybegs
# Processing Record 13 of Set 10 | artyom
# Processing Record 14 of Set 10 | lalibela
# Processing Record 15 of Set 10 | pontianak
# Processing Record 16 of Set 10 | iqaluit
# Processing Record 17 of Set 10 | korla
# Processing Record 18 of Set 10 | chanute
# Processing Record 19 of Set 10 | lensk
# Processing Record 20 of Set 10 | atikokan
# Processing Record 21 of Set 10 | pangkalanbuun
# Processing Record 22 of Set 10 | siguiri
# Processing Record 23 of Set 10 | chabahar
# Processing Record 24 of Set 10 | boaco
# Processing Record 25 of Set 10 | kununurra
# Processing Record 26 of Set 10 | kailua
# Processing Record 27 of Set 10 | bagli
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | tyrma
# Processing Record 30 of Set 10 | skelleftea
# Processing Record 31 of Set 10 | kieta
# Processing Record 32 of Set 10 | oranjemund
# Processing Record 33 of Set 10 | axim
# Processing Record 34 of Set 10 | fairbanks
# Processing Record 35 of Set 10 | repalle
# Processing Record 36 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 37 of Set 10 | burica
# City not found. Skipping...
# Processing Record 38 of Set 10 | bermeo
# Processing Record 39 of Set 10 | sauk rapids
# Processing Record 40 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 10 | chitapur
# Processing Record 42 of Set 10 | ulagan
# Processing Record 43 of Set 10 | santiago del estero
# Processing Record 44 of Set 10 | ano mera
# Processing Record 45 of Set 10 | souillac
# Processing Record 46 of Set 10 | hohhot
# Processing Record 47 of Set 10 | johnstown
# Processing Record 48 of Set 10 | sena madureira
# Processing Record 49 of Set 10 | kolosovka
# Processing Record 50 of Set 10 | talnakh
# Processing Record 1 of Set 11 | yeniseysk
# Processing Record 2 of Set 11 | orsha
# Processing Record 3 of Set 11 | buala
# Processing Record 4 of Set 11 | tecoanapa
# Processing Record 5 of Set 11 | geraldton
# Processing Record 6 of Set 11 | general roca
# Processing Record 7 of Set 11 | shache
# Processing Record 8 of Set 11 | cromarty
# Processing Record 9 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 11 | boda
# Processing Record 11 of Set 11 | abu dhabi
# Processing Record 12 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 11 | algodones
# Processing Record 14 of Set 11 | severnoye
# Processing Record 15 of Set 11 | gari
# Processing Record 16 of Set 11 | noumea
# Processing Record 17 of Set 11 | coahuayana
# Processing Record 18 of Set 11 | paamiut
# Processing Record 19 of Set 11 | awjilah
# Processing Record 20 of Set 11 | lagoa
# Processing Record 21 of Set 11 | narrabri
# Processing Record 22 of Set 11 | jega
# Processing Record 23 of Set 11 | oeiras
# Processing Record 24 of Set 11 | baykit
# Processing Record 25 of Set 11 | turukhansk
# Processing Record 26 of Set 11 | pindi gheb
# Processing Record 27 of Set 11 | carutapera
# Processing Record 28 of Set 11 | breves
# Processing Record 29 of Set 11 | tulu bolo
# Processing Record 30 of Set 11 | bandiagara
# Processing Record 31 of Set 11 | yerofey pavlovich
# Processing Record 32 of Set 11 | burnie
# Processing Record 33 of Set 11 | margate
# Processing Record 34 of Set 11 | lasa
# Processing Record 35 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 11 | bataipora
# Processing Record 37 of Set 11 | belomorsk
# Processing Record 38 of Set 11 | urucara
# Processing Record 39 of Set 11 | ust-koksa
# Processing Record 40 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 11 | nea alikarnassos
# Processing Record 42 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 11 | namatanai
# Processing Record 44 of Set 11 | kalat
# Processing Record 45 of Set 11 | nizhneangarsk
# Processing Record 46 of Set 11 | kivertsi
# Processing Record 47 of Set 11 | honiara
# Processing Record 48 of Set 11 | iralaya
# Processing Record 49 of Set 11 | hailar
# Processing Record 50 of Set 11 | khandagayty
# Processing Record 1 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 12 | nelson bay
# Processing Record 3 of Set 12 | husavik
# Processing Record 4 of Set 12 | chino valley
# Processing Record 5 of Set 12 | kenora
# Processing Record 6 of Set 12 | sao cristovao
# Processing Record 7 of Set 12 | leo
# Processing Record 8 of Set 12 | samandag
# Processing Record 9 of Set 12 | port pirie
# Processing Record 10 of Set 12 | maniitsoq
# Processing Record 11 of Set 12 | qujing
# Processing Record 12 of Set 12 | santa cruz
# Processing Record 13 of Set 12 | mayo
# Processing Record 14 of Set 12 | itarema
# Processing Record 15 of Set 12 | portlethen
# Processing Record 16 of Set 12 | san jacinto
# Processing Record 17 of Set 12 | marzuq
# Processing Record 18 of Set 12 | puerto escondido
# Processing Record 19 of Set 12 | canico
# Processing Record 20 of Set 12 | gryazovets
# Processing Record 21 of Set 12 | binghamton
# Processing Record 22 of Set 12 | tessalit
# Processing Record 23 of Set 12 | ouesso
# Processing Record 24 of Set 12 | gazanjyk
# Processing Record 25 of Set 12 | strezhevoy
# Processing Record 26 of Set 12 | bongandanga
# Processing Record 27 of Set 12 | latung
# Processing Record 28 of Set 12 | mitu
# Processing Record 29 of Set 12 | gandajika
# Processing Record 30 of Set 12 | conakry
# Processing Record 31 of Set 12 | imbituba
# Processing Record 32 of Set 12 | safford
# Processing Record 33 of Set 12 | dali
# Processing Record 34 of Set 12 | alcudia
# Processing Record 35 of Set 12 | fez
# Processing Record 36 of Set 12 | macatuba
# Processing Record 37 of Set 12 | masty
# Processing Record 38 of Set 12 | salalah
# Processing Record 39 of Set 12 | korem
# Processing Record 40 of Set 12 | maningrida
# Processing Record 41 of Set 12 | olinda
# Processing Record 42 of Set 12 | qasigiannguit
# Processing Record 43 of Set 12 | sibu
# Processing Record 44 of Set 12 | malanje
# Processing Record 45 of Set 12 | lokhvytsya
# Processing Record 46 of Set 12 | hue
# Processing Record 47 of Set 12 | egvekinot
# Processing Record 48 of Set 12 | mpanda
# Processing Record 49 of Set 12 | qarqin
# Processing Record 50 of Set 12 | donskoye
# Processing Record 1 of Set 13 | kumburgaz
# Processing Record 2 of Set 13 | ichinoseki
# Processing Record 3 of Set 13 | alappuzha
# Processing Record 4 of Set 13 | murray bridge
# Processing Record 5 of Set 13 | dezful
# Processing Record 6 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 13 | marostica
# Processing Record 8 of Set 13 | prachuap khiri khan
# Processing Record 9 of Set 13 | vrangel
# Processing Record 10 of Set 13 | boa vista
# Processing Record 11 of Set 13 | high level
# Processing Record 12 of Set 13 | abnub
# Processing Record 13 of Set 13 | vila franca do campo
# Processing Record 14 of Set 13 | ouadda
# Processing Record 15 of Set 13 | tilichiki
# Processing Record 16 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 13 | cordoba
# Processing Record 18 of Set 13 | dakar
# Processing Record 19 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 13 | mareeba
# Processing Record 21 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 22 of Set 13 | kapit
# Processing Record 23 of Set 13 | vallenar
# Processing Record 24 of Set 13 | hatsukaichi
# Processing Record 25 of Set 13 | bandarbeyla
# Processing Record 26 of Set 13 | kautokeino
# Processing Record 27 of Set 13 | nuevo cuscatlan
# Processing Record 28 of Set 13 | oktyabrskoye
# Processing Record 29 of Set 13 | sola
# Processing Record 30 of Set 13 | luderitz
# Processing Record 31 of Set 13 | zyryanka
# Processing Record 32 of Set 13 | ayagoz
# Processing Record 33 of Set 13 | lakes entrance
# Processing Record 34 of Set 13 | uusikaupunki
# Processing Record 35 of Set 13 | kalmunai
# Processing Record 36 of Set 13 | amlagora
# Processing Record 37 of Set 13 | strelka
# Processing Record 38 of Set 13 | fort smith
# Processing Record 39 of Set 13 | nizwa
# Processing Record 40 of Set 13 | cilibia
# Processing Record 41 of Set 13 | tuatapere
# Processing Record 42 of Set 13 | atherton
# Processing Record 43 of Set 13 | west fargo
# Processing Record 44 of Set 13 | kuusamo
# Processing Record 45 of Set 13 | tuy hoa
# Processing Record 46 of Set 13 | trincomalee
# Processing Record 47 of Set 13 | bereda
# Processing Record 48 of Set 13 | rota
# Processing Record 49 of Set 13 | santiago
# Processing Record 50 of Set 13 | lorengau
# Processing Record 1 of Set 14 | moree
# Processing Record 2 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 14 | maldonado
# Processing Record 4 of Set 14 | langsa
# Processing Record 5 of Set 14 | sarmanovo
# Processing Record 6 of Set 14 | barranco
# Processing Record 7 of Set 14 | waipawa
# Processing Record 8 of Set 14 | shetpe
# Processing Record 9 of Set 14 | la asuncion
# Processing Record 10 of Set 14 | iacobeni
# Processing Record 11 of Set 14 | pandan niog
# Processing Record 12 of Set 14 | calama
# Processing Record 13 of Set 14 | ust-nera
# Processing Record 14 of Set 14 | homer
# Processing Record 15 of Set 14 | sorgun
# Processing Record 16 of Set 14 | midland
# Processing Record 17 of Set 14 | mayumba
# Processing Record 18 of Set 14 | saint-georges
# Processing Record 19 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 14 | palu
# Processing Record 21 of Set 14 | manavalakurichi
# Processing Record 22 of Set 14 | ulladulla
# Processing Record 23 of Set 14 | haverfordwest
# Processing Record 24 of Set 14 | pishin
# Processing Record 25 of Set 14 | solnechnyy
# Processing Record 26 of Set 14 | guapimirim
# Processing Record 27 of Set 14 | jomalig
# City not found. Skipping...
# Processing Record 28 of Set 14 | taltal
# Processing Record 29 of Set 14 | sandnessjoen
# Processing Record 30 of Set 14 | erenhot
# Processing Record 31 of Set 14 | yeppoon
# Processing Record 32 of Set 14 | mpongwe
# Processing Record 33 of Set 14 | san rafael
# Processing Record 34 of Set 14 | sobolevo
# Processing Record 35 of Set 14 | catamarca
# Processing Record 36 of Set 14 | le port
# Processing Record 37 of Set 14 | bozhou
# Processing Record 38 of Set 14 | dandong
# Processing Record 39 of Set 14 | kungurtug
# Processing Record 40 of Set 14 | yekimovichi
# Processing Record 41 of Set 14 | galesong
# Processing Record 42 of Set 14 | kyshtovka
# Processing Record 43 of Set 14 | altay
# Processing Record 44 of Set 14 | khandbari
# Processing Record 45 of Set 14 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 46 of Set 14 | gimli
# Processing Record 47 of Set 14 | anadyr
# Processing Record 48 of Set 14 | east hemet
# Processing Record 49 of Set 14 | chateauroux
# Processing Record 50 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 15 | sinnamary
# Processing Record 2 of Set 15 | aswan
# Processing Record 3 of Set 15 | vezirkopru
# Processing Record 4 of Set 15 | port macquarie
# Processing Record 5 of Set 15 | dudinka
# Processing Record 6 of Set 15 | ardahan
# Processing Record 7 of Set 15 | botwood
# Processing Record 8 of Set 15 | acarau
# Processing Record 9 of Set 15 | chau doc
# Processing Record 10 of Set 15 | biking
# Processing Record 11 of Set 15 | oriximina
# Processing Record 12 of Set 15 | mandalgovi
# Processing Record 13 of Set 15 | kutum
# Processing Record 14 of Set 15 | colac
# Processing Record 15 of Set 15 | henties bay
# Processing Record 16 of Set 15 | stokmarknes
# Processing Record 17 of Set 15 | shubarshi
# Processing Record 18 of Set 15 | amurrio
# Processing Record 19 of Set 15 | verkhnyaya inta
# Processing Record 20 of Set 15 | moron
# Processing Record 21 of Set 15 | las palmas
# Processing Record 22 of Set 15 | half moon bay
# Processing Record 23 of Set 15 | lithakia
# Processing Record 24 of Set 15 | quang ngai
# Processing Record 25 of Set 15 | mildura
# Processing Record 26 of Set 15 | cayenne
# Processing Record 27 of Set 15 | ambilobe
# Processing Record 28 of Set 15 | varska
# City not found. Skipping...
# Processing Record 29 of Set 15 | alberton
# Processing Record 30 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 15 | itaocara
# Processing Record 33 of Set 15 | warri
# Processing Record 34 of Set 15 | mlonggo
# Processing Record 35 of Set 15 | gazli
# Processing Record 36 of Set 15 | kurumkan
# Processing Record 37 of Set 15 | moerai
# Processing Record 38 of Set 15 | murupara
# Processing Record 39 of Set 15 | agadez
# Processing Record 40 of Set 15 | dharmanagar
# Processing Record 41 of Set 15 | parabel
# Processing Record 42 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 43 of Set 15 | churapcha
# Processing Record 44 of Set 15 | jonesboro
# Processing Record 45 of Set 15 | norsup
# Processing Record 46 of Set 15 | pudozh
# Processing Record 47 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 48 of Set 15 | holme
# Processing Record 49 of Set 15 | palmer
# Processing Record 50 of Set 15 | warin chamrap
# Processing Record 1 of Set 16 | griffith
# Processing Record 2 of Set 16 | tomatlan
# Processing Record 3 of Set 16 | brownsville
# Processing Record 4 of Set 16 | khowst
# Processing Record 5 of Set 16 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 16 | nieuw amsterdam
# Processing Record 7 of Set 16 | bibbiena
# Processing Record 8 of Set 16 | abbeville
# Processing Record 9 of Set 16 | asau
# Processing Record 10 of Set 16 | porto novo
# Processing Record 11 of Set 16 | matagami
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Yima  34.7381  111.8839     99.68        21          17
# 1      Gorontalo   0.5412  123.0595     79.14        90         100
# 2        Qaanaaq  77.4840  -69.3632     33.55        79         100
# 3   Puerto Ayora  -0.7393  -90.3518     69.55        96          80
# 4         Dikson  73.5069   80.5464     35.62        79          97
# 5     Butaritari   3.0707  172.7902     81.28        79           6
# 6        Mataura -46.1927  168.8643     43.48        96          99
# 7  Leningradskiy  69.3833  178.4167     43.27        77          96
# 8        Ushuaia -54.8000  -68.3000     28.06        93         100
# 9          Vaini -21.2000 -175.2000     76.62        88          69
#
#    Wind Speed Country Current Description
# 0       20.11      CN          few clouds
# 1        1.79      ID     overcast clouds
# 2        6.53      GL     overcast clouds
# 3        4.00      EC       broken clouds
# 4       11.92      RU     overcast clouds
# 5        6.64      KI          light rain
# 6        1.72      NZ     overcast clouds
# 7        8.68      RU          light rain
# 8        9.22      AR          light snow
# 9       19.71      TO       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Yima      CN  34.7381  111.8839     99.68        21          17
# 1      Gorontalo      ID   0.5412  123.0595     79.14        90         100
# 2        Qaanaaq      GL  77.4840  -69.3632     33.55        79         100
# 3   Puerto Ayora      EC  -0.7393  -90.3518     69.55        96          80
# 4         Dikson      RU  73.5069   80.5464     35.62        79          97
# 5     Butaritari      KI   3.0707  172.7902     81.28        79           6
# 6        Mataura      NZ -46.1927  168.8643     43.48        96          99
# 7  Leningradskiy      RU  69.3833  178.4167     43.27        77          96
# 8        Ushuaia      AR -54.8000  -68.3000     28.06        93         100
# 9          Vaini      TO -21.2000 -175.2000     76.62        88          69
#
#    Wind Speed Current Description
# 0       20.11          few clouds
# 1        1.79     overcast clouds
# 2        6.53     overcast clouds
# 3        4.00       broken clouds
# 4       11.92     overcast clouds
# 5        6.64          light rain
# 6        1.72     overcast clouds
# 7        8.68          light rain
# 8        9.22          light snow
# 9       19.71       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
city_data_df= pd.read_csv(output_data_file)
